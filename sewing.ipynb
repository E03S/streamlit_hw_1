# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('combined.csv')

# %%
f = plt.figure()
plt.matshow(data.corr(), fignum=f.number)
plt.colorbar()
plt.show()
